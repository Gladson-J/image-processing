# %%
pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.20.0-cp39-cp39-win_amd64.whl (23.9 MB)
#      ---------------------------------------- 23.9/23.9 MB 6.1 MB/s eta 0:00:00
# Collecting lazy_loader>=0.1
#   Downloading lazy_loader-0.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\sn150\anaconda3\envs\gladson_ai\lib\site-packages (from scikit-image) (1.24.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\sn150\anaconda3\envs\gladson_ai\lib\site-packages (from scikit-image) (9.4.0)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp39-cp39-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 12.7 MB/s eta 0:00:00
# Collecting networkx>=2.8
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 5.9 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.26.1-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 11.3 MB/s eta 0:00:00
# Collecting scipy<1.9.2,>=1.8
#   Downloading scipy-1.9.1-cp39-cp39-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 5.8 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2023.3.15-py3-none-any.whl (218 kB)
#      ------------------------------------ 218.6/218.6 kB 955.8 kB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\sn150\anaconda3\envs\gladson_ai\lib\site-packages (from scikit-image) (22.0)
# Installing collected packages: tifffile, scipy, PyWavelets, networkx, lazy_loader, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.26.1 lazy_loader-0.1 networkx-3.0 scikit-image-0.20.0 scipy-1.9.1 tifffile-2023.3.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.feature import hog
from skimage import data,exposure

# %%
img=cv2.imread("nature1.jpg")

# %%
fd,hog_image=hog(img,orientations=9,pixels_per_cell=(8,8),cells_per_block=(2,2),visualize=True,channel_axis=2)

# %%
rescale=exposure.rescale_intensity(hog_image,in_range=(0,10))

# %%
figure,(a1,a2)=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
a1.axis('off')
a1.imshow(img)
a1.set_title('input image')
a2.axis('off')
a2.imshow(rescale)
a2.set_title('hog_image')
plt.show()

# %%
pip install imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25847 sha256=749a6e89bd70ba65fc47c3c708497dd4a53660c070879082a035b020c89051fa
#   Stored in directory: c:\users\sn150\appdata\local\pip\cache\wheels\f4\4b\8b\a9c23da464a09c6ad0a131c1752079bc85f9f1677c7b78e87d
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import imutils

# %%
hog=cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
#img reading
img=cv2.imread("people.jpg")
#resize
image=imutils.resize(img,width=min(400,img.shape[1]))
#detecting all the regions in the image
(regions,img)=hog.detectMultiScale(image,winStride=(2,2),
                                          padding=(4,4),
                                          scale=1.05)
#drawing regions
for(x,y,w,h)in regions:
    cv2.rectangle(image,(x,y),
               (x+w,y+h),
               (0,255,0),2)
    
cv2.imshow("IMAGE",image)
cv2.waitKey(0)
# Out:
# -1
